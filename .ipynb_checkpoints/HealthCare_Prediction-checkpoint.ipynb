# %%
# 1. Manipulação e Análise de Dados
import pandas as pd
import numpy as np
# 2. Visualização de Dados (Foco em Interatividade)
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# 3. Pré-processamento e Divisão de Dados
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, RobustScaler
# 4. Modelagem
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
# 5. Métricas de Avaliação (Foco em Saúde/Healthcare)
from sklearn.metrics import (
    classification_report, 
    confusion_matrix, 
    roc_auc_score, 
    roc_curve, 
    f1_score
)
# 6. Interpretabilidade do Modelo
import shap

import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
df = pd.read_csv('heart_failure_clinical_records_dataset.csv')
df_traduzido_pt_br = df.rename(columns={
    'age' : "Idade",
    'anaemia' : 'Anemia',
    'creatinine_phosphokinase' : 'Creatina Fosfoquinase',
    'ejection_fraction' : 'Fração de Ejeção',
    'high_blood_pressure' : 'Pressão Alta',
    'platelets' : 'Plaquetas',
    'serum_creatinine' : 'Creatinina Sérica',
    'serum_sodium' : 'Sódio Sérico',
    'sex' : 'Sexo',
    'diabetes' : 'Diabetes',
    'smoking' : 'Fumante',
    'time' : 'Tempo',
    'DEATH_EVENT' : 'Evento de Óbito'
})
df_traduzido_pt_br.head()
# Out:
#    Idade  Anemia  Creatina Fosfoquinase  Diabetes  Fração de Ejeção  \
# 0   75.0       0                    582         0                20
# 1   55.0       0                   7861         0                38
# 2   65.0       0                    146         0                20
# 3   50.0       1                    111         0                20
# 4   65.0       1                    160         1                20
#
#    Pressão Alta  Plaquetas  Creatinina Sérica  Sódio Sérico  Sexo  Fumante  \
# 0             1  265000.00                1.9           130     1        0
# 1             0  263358.03                1.1           136     1        0
# 2             0  162000.00                1.3           129     1        1
# 3             0  210000.00                1.9           137     1        0
# 4             0  327000.00                2.7           116     0        0
#
#    Tempo  Evento de Óbito
# 0      4                1
# 1      6                1
# 2      7                1
# 3      7                1
# 4      8                1

# %%
# 1. Lista todas as colunas do DataFrame
print("Colunas encontradas no dataset:")
print(df.columns.tolist())

# 2. Verifica se há espaços em branco invisíveis (comum em CSVs)
# Exemplo: ' DEATH_EVENT' em vez de 'DEATH_EVENT'
print("\nVerificando espaços extras:")
print([f"'{col}'" for col in df.columns])

# 3. DICA DE OURO: Limpeza automática de nomes de colunas
# Remove espaços no início/fim e garante que o código não quebre por bobeira
df.columns = df.columns.str.strip()
print("\nColunas após o strip (limpeza):")
print(df.columns.tolist())
# Out:
# Colunas encontradas no dataset:
# ['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes', 'ejection_fraction', 'high_blood_pressure', 'platelets', 'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time', 'DEATH_EVENT']
#
# Verificando espaços extras:
# ["'age'", "'anaemia'", "'creatinine_phosphokinase'", "'diabetes'", "'ejection_fraction'", "'high_blood_pressure'", "'platelets'", "'serum_creatinine'", "'serum_sodium'", "'sex'", "'smoking'", "'time'", "'DEATH_EVENT'"]
#
# Colunas após o strip (limpeza):
# ['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes', 'ejection_fraction', 'high_blood_pressure', 'platelets', 'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time', 'DEATH_EVENT']

# %%
# Criando um dicionário explicativo para leigos
dados_explicativos = {
    'Coluna': [
        'Tempo', 'Creatinina Sérica', 'Fração de Ejeção', 'Idade', 
        'Sódio Sérico', 'CPK (Enzima)', 'Plaquetas', 'Pressão Alta', 
        'Anemia', 'Diabetes', 'Fumante', 'Sexo'
    ],
    'O que representa na Saúde?': [
        'Dias de acompanhamento médico do paciente.',
        'Nível de resíduo no sangue; indica se os Rins estão funcionando bem.',
        'Porcentagem de sangue que o coração consegue bombear (força do coração).',
        'Idade cronológica do paciente.',
        'Equilíbrio de sais minerais e hidratação no corpo.',
        'Proteína que aumenta no sangue quando há lesão no músculo do coração.',
        'Células que ajudam na coagulação do sangue.',
        'Se o paciente possui diagnóstico de hipertensão.',
        'Redução de glóbulos vermelhos, o que diminui o transporte de oxigênio.',
        'Presença de níveis elevados de açúcar no sangue.',
        'Se o paciente possui o hábito de fumar.',
        'Gênero biológico do paciente.'
    ]
}

# Transformando em um DataFrame para exibição bonita
df_ajuda = pd.DataFrame(dados_explicativos)

# %%
# 1. Definindo X (características) e y (alvo)
X = df_traduzido_pt_br.drop('Evento de Óbito', axis=1)
y = df_traduzido_pt_br['Evento de Óbito']

# 2. Divisão Treino/Teste (essencial para não viciar o modelo)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 3. Escalonamento (Uso do StandardScaler)
# Importante: Ajustamos o scaler apenas no treino para evitar "Data Leakage"
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f"Dados prontos! Treino: {X_train.shape[0]} amostras, Teste: {X_test.shape[0]} amostras.")
# Out:
# Dados prontos! Treino: 209 amostras, Teste: 90 amostras.

# %%
# Treinando o XGBoost (O modelo de alta performance)
xgb_model = XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
xgb_model.fit(X_train_scaled, y_train)

# Treinando a RandomForest (O modelo de conjunto robusto)
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_scaled, y_train)

print("Modelos treinados com sucesso!")
# Out:
# Modelos treinados com sucesso!

# %%
# 1. Definindo X (características) e y (alvo) usando os nomes traduzidos
# Note que 'diabetes' não estava no seu rename, então ele permanece como 'diabetes'
X = df_traduzido_pt_br.drop('Evento de Óbito', axis=1)
y = df_traduzido_pt_br['Evento de Óbito']

# 2. Divisão Treino/Teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 3. Escalonamento
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 4. Treinamento do Modelo (XGBoost)
xgb_model = XGBClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
xgb_model.fit(X_train_scaled, y_train)

# 5. Visualização do Desempenho (Matriz de Confusão com Plotly)
y_pred = xgb_model.predict(X_test_scaled)
cm = confusion_matrix(y_test, y_pred)

fig = px.imshow(cm, text_auto=True, 
                x=['Previsão: Sobreviveu', 'Previsão: Óbito'], 
                y=['Real: Sobreviveu', 'Real: Óbito'],
                color_continuous_scale='RdBu_r',
                title="<b>Matriz de Confusão (Dados Traduzidos)</b>")
fig.show()

# %%
# Extraindo a importância do modelo
importancias = xgb_model.feature_importances_
feature_names = X.columns

# Criando um DataFrame temporário para o gráfico
df_importancia = pd.DataFrame({'Atributo': feature_names, 'Importancia': importancias})
df_importancia = df_importancia.sort_values(by='Importancia', ascending=True)

# Gerando o gráfico de barras horizontais
fig = px.bar(df_importancia, x='Importancia', y='Atributo', orientation='h',
             title="<b>Ranking de Relevância Clínica</b>",
             labels={'Importancia': 'Poder de Predição', 'Atributo': 'Exame Médico'},
             color='Importancia', color_continuous_scale='Viridis')

fig.update_layout(yaxis={'categoryorder':'total ascending'}, title_x=0.5)
fig.show()

# %%
def analisar_paciente(dados_paciente):
    """
    Função para analisar os dados de um único paciente e retornar a previsão.
    Input: Dicionário com as mesmas colunas do X (em português).
    """
    # 1. Converter o dicionário em DataFrame
    novo_df = pd.DataFrame([dados_paciente])
    
    # 2. Aplicar o Scaler (importante: o modelo não entende números brutos, apenas escalonados)
    novo_df_scaled = scaler.transform(novo_df)
    
    # 3. Fazer a previsão
    previsao = xgb_model.predict(novo_df_scaled)[0]
    probabilidade = xgb_model.predict_proba(novo_df_scaled)[0][1] # Chance de Óbito
    
    # 4. Formatar a resposta
    resultado = "⚠️ ALTO RISCO (Óbito)" if previsao == 1 else "✅ BAIXO RISCO (Sobrevivência)"
    
    print("-" * 30)
    print(f"RESULTADO DA ANÁLISE: {resultado}")
    print(f"Probabilidade estimada de óbito: {probabilidade:.2%}")
    print("-" * 30)

# --- EXEMPLO DE USO ---
# Você pode alterar esses números para testar o modelo:
exemplo_paciente = {
    'Idade': 65,
    'Anemia': 1,
    'Creatina Fosfoquinase': 250,
    'Diabetes': 0,
    'Fração de Ejeção': 20, # Valor baixo (ruim)
    'Pressão Alta': 1,
    'Plaquetas': 265000,
    'Creatinina Sérica': 1.9, # Valor alto (ruim)
    'Sódio Sérico': 130,
    'Sexo': 1,
    'Fumante': 1,
    'Tempo': 10 # Pouco tempo de acompanhamento (ruim)
}

analisar_paciente(exemplo_paciente)
# Out:
# ------------------------------
# RESULTADO DA ANÁLISE: ⚠️ ALTO RISCO (Óbito)
# Probabilidade estimada de óbito: 98.84%
# ------------------------------

# %%
def analise_detalhada_paciente(dados_paciente):
    # 1. Preparação dos dados
    novo_df = pd.DataFrame([dados_paciente])
    novo_df_scaled = scaler.transform(novo_df)
    
    # 2. Cálculo do SHAP para este paciente específico
    explainer_individual = shap.TreeExplainer(xgb_model)
    shap_values_paciente = explainer_individual.shap_values(novo_df_scaled)
    
    # 3. Predição de Probabilidade
    prob = xgb_model.predict_proba(novo_df_scaled)[0][1]
    
    print(f"--- RELATÓRIO DE RISCO ADAPTATIVO ---")
    print(f"Probabilidade Atual: {prob:.2%}")
    
    # 4. Identificando os vilões (o que aumenta o risco) e os heróis (o que baixa)
    # Criamos um dicionário pareando o nome da coluna com o valor SHAP
    impactos = dict(zip(X.columns, shap_values_paciente[0]))
    
    fatores_risco = {k: v for k, v in impactos.items() if v > 0}
    fatores_protecao = {k: v for k, v in impactos.items() if v < 0}
    
    print("\n🚩 FATORES QUE ESTÃO AUMENTANDO O RISCO:")
    for k, v in sorted(fatores_risco.items(), key=lambda item: item[1], reverse=True)[:3]:
        print(f"-> {k}: Está impactando positivamente no risco (mudar este quadro é prioritário).")

    print("\n🛡️ FATORES QUE ESTÃO PROTEGENDO O PACIENTE:")
    for k, v in sorted(fatores_protecao.items(), key=lambda item: item[1])[:3]:
        print(f"-> {k}: Este fator está ajudando a manter o paciente estável.")

    # 5. Simulação de Melhora (Como baixar a porcentagem)
    print("\n💡 COMO BAIXAR ESSE RISCO?")
    if 'Creatinina Sérica' in fatores_risco:
        print("- Estabilizar a função renal (reduzir Creatinina Sérica) teria o maior impacto imediato.")
    if 'Fração de Ejeção' in fatores_risco:
        print("- Melhorar a capacidade de bombeamento cardíaco (aumentar Fração de Ejeção) é vital.")
    if 'Fumante' in fatores_risco and dados_paciente['Fumante'] == 1:
        print("- A cessação imediata do tabagismo removeria um peso crítico da carga do modelo.")

# Testando com o exemplo anterior
analise_detalhada_paciente(exemplo_paciente)
# Out:
# --- RELATÓRIO DE RISCO ADAPTATIVO ---
# Probabilidade Atual: 98.84%
#
# 🚩 FATORES QUE ESTÃO AUMENTANDO O RISCO:
# -> Tempo: Está impactando positivamente no risco (mudar este quadro é prioritário).
# -> Fração de Ejeção: Está impactando positivamente no risco (mudar este quadro é prioritário).
# -> Creatinina Sérica: Está impactando positivamente no risco (mudar este quadro é prioritário).
#
# 🛡️ FATORES QUE ESTÃO PROTEGENDO O PACIENTE:
# -> Sexo: Este fator está ajudando a manter o paciente estável.
# -> Plaquetas: Este fator está ajudando a manter o paciente estável.
# -> Pressão Alta: Este fator está ajudando a manter o paciente estável.
#
# 💡 COMO BAIXAR ESSE RISCO?
# - Estabilizar a função renal (reduzir Creatinina Sérica) teria o maior impacto imediato.
# - Melhorar a capacidade de bombeamento cardíaco (aumentar Fração de Ejeção) é vital.
# - A cessação imediata do tabagismo removeria um peso crítico da carga do modelo.

# %%
def analise_interativa_de_risco(dados_paciente):
    # 1. Preparação e Predição
    novo_df = pd.DataFrame([dados_paciente])
    novo_df_scaled = scaler.transform(novo_df)
    
    prob_atual = xgb_model.predict_proba(novo_df_scaled)[0][1]
    
    print(f"===  RELATÓRIO DE INTERVENÇÃO CLÍNICA ===")
    print(f"Risco de óbito calculado: {prob_atual:.2%}")
    print("-" * 45)
    print("ANÁLISE DE FATORES E RECOMENDAÇÕES:\n")

    # 2. Diagnóstico por variáveis (Os 'IFs' de intervenção)
    
    # FRAÇÃO DE EJEÇÃO (Normalmente acima de 50-55%)
    if dados_paciente['Fração de Ejeção'] < 40:
        print(f" ALERTA: Fração de Ejeção baixa ({dados_paciente['Fração de Ejeção']}%).")
        print("   -> Ação: Fortalecer o bombeamento cardíaco através de medicação ou terapia.\n")
    
    # CREATININA SÉRICA (Normalmente entre 0.7 e 1.3 mg/dL)
    if dados_paciente['Creatinina Sérica'] > 1.3:
        print(f" ALERTA: Creatinina elevada ({dados_paciente['Creatinina Sérica']} mg/dL).")
        print("   -> Ação: Monitorar função renal. Hidratação e revisão de medicamentos nefrotóxicos.\n")
    
    # SÓDIO SÉRICO (Normal entre 135-145 mEq/L)
    if dados_paciente['Sódio Sérico'] < 135:
        print(f" ALERTA: Hiponatremia detectada ({dados_paciente['Sódio Sérico']} mEq/L).")
        print("   -> Ação: Reposição de eletrólitos e balanço hídrico.\n")

    # TABAGISMO
    if dados_paciente['Fumante'] == 1:
        print(" ALERTA: Paciente fumante ativo.")
        print("   -> Ação: Cessação tabágica imediata. Reduziria o estresse oxidativo e inflamação.\n")

    # TEMPO DE ACOMPANHAMENTO (Variável crítica no seu SHAP)
    if dados_paciente['Tempo'] < 50:
        print(f" OBSERVAÇÃO: Tempo de acompanhamento curto ({dados_paciente['Tempo']} dias).")
        print("   -> Ação: Intensificar consultas no primeiro trimestre pós-evento.\n")

    # 3. Simulação de "Cenário Ideal"
    # Criamos um clone do paciente "curado" para mostrar a queda no risco
    paciente_ideal = dados_paciente.copy()
    paciente_ideal['Fumante'] = 0
    paciente_ideal['Creatinina Sérica'] = 1.0
    paciente_ideal['Fração de Ejeção'] = 50
    
    ideal_scaled = scaler.transform(pd.DataFrame([paciente_ideal]))
    prob_ideal = xgb_model.predict_proba(ideal_scaled)[0][1]
    
    print("-" * 45)
    print(f"💡 IMPACTO DAS MUDANÇAS:")
    print(f"Se estabilizarmos os fatores acima, o risco cai de {prob_atual:.2%} para {prob_ideal:.2%}.")
    print(f"Uma redução real de {(prob_atual - prob_ideal):.2%} na chance de óbito.")

# Teste com o paciente de risco
analise_interativa_de_risco(exemplo_paciente)
# Out:
# ===  RELATÓRIO DE INTERVENÇÃO CLÍNICA ===
# Risco de óbito calculado: 98.84%
# ---------------------------------------------
# ANÁLISE DE FATORES E RECOMENDAÇÕES:
#
#  ALERTA: Fração de Ejeção baixa (20%).
#    -> Ação: Fortalecer o bombeamento cardíaco através de medicação ou terapia.
#
#  ALERTA: Creatinina elevada (1.9 mg/dL).
#    -> Ação: Monitorar função renal. Hidratação e revisão de medicamentos nefrotóxicos.
#
#  ALERTA: Hiponatremia detectada (130 mEq/L).
#    -> Ação: Reposição de eletrólitos e balanço hídrico.
#
#  ALERTA: Paciente fumante ativo.
#    -> Ação: Cessação tabágica imediata. Reduziria o estresse oxidativo e inflamação.
#
#  OBSERVAÇÃO: Tempo de acompanhamento curto (10 dias).
#    -> Ação: Intensificar consultas no primeiro trimestre pós-evento.
#
# ---------------------------------------------
# 💡 IMPACTO DAS MUDANÇAS:
# Se estabilizarmos os fatores acima, o risco cai de 98.84% para 93.98%.
# Uma redução real de 4.86% na chance de óbito.

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import plotly.express as px
import pandas as pd

# 1. CSS E IDENTIDADE VISUAL
css_saude = """
<style>
    @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@400;600&display=swap');
    .dashboard-main { font-family: 'Montserrat', sans-serif; }
    
    .widget-dropdown > select {
        background-color: #27ae60 !important;
        color: white !important;
        font-weight: 600 !important;
        font-size: 15px !important;
        border-radius: 12px !important;
        height: 45px !important;
        line-height: 35px !important;
        padding: 0 15px !important;
        border: none !important;
        box-shadow: 0 4px 10px rgba(0,0,0,0.1) !important;
        cursor: pointer;
    }

    .widget-label {
        min-width: 140px !important;
        font-family: 'Montserrat', sans-serif !important;
        font-weight: bold !important;
        color: #2c3e50 !important;
        font-size: 14px !important;
    }

    .tabela-guia th { background-color: #219150; color: white; padding: 12px; text-align: left; }
    .tabela-guia td { padding: 10px; border-bottom: 1px solid #eee; font-size: 14px; }
</style>
"""

# 2. COMPONENTES DE INTERFACE
header = widgets.HTML(
    "<div style='background: linear-gradient(135deg, #1e8449, #27ae60); color: white; padding: 25px; border-radius: 15px; margin-bottom: 10px;'>"
    "  <h2 style='margin:0;'> Estudo de Registros Clínicos de Insuficiência Cardíaca </h2>"
    "  <p style='margin:5px 0 0 0; opacity: 0.9;'>Análise de Relevância e Glossário de Saúde</p>"
    "</div>"
)

seletor = widgets.Dropdown(
    options=[('🏆 Ranking de Relevância', 'ranking'), ('📈 Distribuição Etária', 'dist'), ('🔍 Matriz de Precisão', 'cm')],
    value='ranking',
    description='VISUALIZAÇÃO:',
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='450px')
)

output_plot = widgets.Output(layout=widgets.Layout(
    width='100%',
    min_height='650px', 
    height='auto',      
    margin='20px 0 50px 0'
))

guia_html = widgets.HTML(
    "<div style='margin-top: 30px; border-top: 2px solid #27ae60; padding-top: 20px;'>"
    "<h3 style='color: #1e8449; font-family: Montserrat;'> Guia de Referência de Atributos</h3>" +
    df_ajuda.style.set_table_attributes('class="tabela-guia" style="width:100%;"')
    .set_properties(**{'text-align': 'left'})
    .hide(axis='index').to_html() +
    "</div>"
)

# 3. LÓGICA DE ATUALIZAÇÃO
def atualizar(change):
    with output_plot:
        clear_output(wait=True)
        escolha = seletor.value
        
        if escolha == 'ranking':
            fig = px.bar(df_importancia, x='Importancia', y='Atributo', orientation='h',
                         title="<b>Peso de Decisão por Exame</b>",
                         color='Importancia', color_continuous_scale='Greens')
            fig.update_layout(yaxis={'categoryorder':'total ascending'}, font_family="Montserrat", 
                              title_x=0.5, height=550, margin=dict(t=60, b=40))
            fig.show()
            
        elif escolha == 'dist':
            fig = px.histogram(df_traduzido_pt_br, x="Idade", color="Evento de Óbito",
                               marginal="box", title="Distribuição de Risco por Faixa Etária",
                               color_discrete_map={0: '#27ae60', 1: '#c0392b'})
            fig.update_layout(font_family="Montserrat", title_x=0.5, height=550)
            fig.show()
            
        elif escolha == 'cm':
            fig = px.imshow(cm, text_auto=True, x=['Vivo', 'Óbito'], y=['Real: Vivo', 'Real: Óbito'],
                            color_continuous_scale='Greens', title="Matriz de Confusão")
            fig.update_layout(font_family="Montserrat", title_x=0.5, height=550)
            fig.show()

seletor.observe(atualizar, names='value')

# 4. EXIBIÇÃO FINAL
dashboard = widgets.VBox([
    widgets.HTML(css_saude),
    header,
    widgets.Box([seletor], layout=widgets.Layout(
        justify_content='center', 
        margin='20px 0 80px 0' 
    )),
    output_plot,
    guia_html
], layout=widgets.Layout(
    padding='20px',
    height='auto',
    overflow='visible'
))

display(dashboard)
atualizar(None)
# Out:
# VBox(children=(HTML(value="\n<style>\n    @import url('https://fonts.googleapis.com/css2?family=Montserrat:wgh…

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

# --- 1. Estilização e Cabeçalho ---
header = widgets.HTML(
    "<h1 style='text-align: center; color: #2c3e50;'>🏥PAINEL DE CONTROLE CLÍNICO </h1>"
    "<p style='text-align: center; color: #7f8c8d;'>Sistema de Apoio à Decisão Clínica - Engenharia de Computação UFG</p>"
    "<hr>"
)

# --- 2. Painel de Input (Usando EXATAMENTE os nomes do seu rename) ---
style = {'description_width': 'initial'}
layout_input = widgets.Layout(width='95%', margin='5px 0')

# Mapeamos os widgets com as chaves idênticas às colunas do seu X
inputs = {
    'Idade': widgets.IntSlider(value=60, min=40, max=95, description='Idade:', style=style, layout=layout_input),
    'Anemia': widgets.Dropdown(options=[('Não', 0), ('Sim', 1)], description='Anemia:', style=style, layout=layout_input),
    'Creatina Fosfoquinase': widgets.IntText(value=250, description='Creatina Fosfoquinase:', style=style, layout=layout_input),
    'Diabetes': widgets.Dropdown(options=[('Não', 0), ('Sim', 1)], description='Diabetes:', style=style, layout=layout_input),
    'Fração de Ejeção': widgets.IntSlider(value=38, min=10, max=80, description='Fração de Ejeção (%):', style=style, layout=layout_input),
    'Pressão Alta': widgets.Dropdown(options=[('Não', 0), ('Sim', 1)], description='Pressão Alta:', style=style, layout=layout_input),
    'Plaquetas': widgets.FloatText(value=265000, description='Plaquetas:', style=style, layout=layout_input),
    'Creatinina Sérica': widgets.FloatSlider(value=1.1, min=0.5, max=9.4, step=0.1, description='Creatinina Sérica:', style=style, layout=layout_input),
    'Sódio Sérico': widgets.IntSlider(value=137, min=110, max=150, description='Sódio Sérico:', style=style, layout=layout_input),
    'Sexo': widgets.Dropdown(options=[('Feminino', 0), ('Masculino', 1)], description='Sexo:', style=style, layout=layout_input),
    'Fumante': widgets.Dropdown(options=[('Não', 0), ('Sim', 1)], description='Fumante:', style=style, layout=layout_input),
    'Tempo': widgets.IntSlider(value=100, min=4, max=285, description='Tempo de Acompanhamento:', style=style, layout=layout_input)
}

painel_esquerdo = widgets.VBox(list(inputs.values()), layout=widgets.Layout(padding='10px', border='1px solid #ddd', width='40%'))
output_display = widgets.Output(layout=widgets.Layout(padding='10px', border='1px solid #ddd', width='58%', min_height='450px'))

btn_analisar = widgets.Button(
    description="🚀 RODAR ANÁLISE PREDITIVA", 
    button_style='primary', 
    layout=widgets.Layout(width='100%', height='50px', margin='10px 0')
)

# --- 3. Lógica Blindada ---
def processar(b):
    with output_display:
        clear_output()
        # Coleta valores
        dados_paciente = {label: widget.value for label, widget in inputs.items()}
        
        # Cria DataFrame e garante a ORDEM das colunas do treino
        novo_df = pd.DataFrame([dados_paciente])
        
        try:
            # Reordena para evitar o erro de Feature Names
            novo_df = novo_df[X.columns]
            
            # Executa predição e os IFs de diagnóstico
            analise_interativa_de_risco(dados_paciente)
            
        except Exception as e:
            print(f"Erro técnico ao processar: {e}")

btn_analisar.on_click(processar)

# --- 4. Exibição ---
corpo = widgets.HBox([painel_esquerdo, output_display])
dashboard = widgets.VBox([header, btn_analisar, corpo])
display(dashboard)
# Out:
# VBox(children=(HTML(value="<h1 style='text-align: center; color: #2c3e50;'>🏥PAINEL DE CONTROLE CLÍNICO </h1><p…
